# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# seaborn==0.10.0
# pandas==1.0.1
# numpy==1.18.1
# matplotlib==3.1.3

# %%
def get_state(data, t, n):
    d = t - n + 1
    block = data[d : t + 1] if d >= 0 else -d * [data[0]] + data[0 : t + 1]
    res = []
    for i in range(n - 1):
        res.append(block[i + 1] - block[i])
    return np.array([res])

# %% [markdown]
# TSLA Time Period: **Mar 23, 2018 - Mar 23, 2019**

# %%
df = pd.read_csv('../dataset/TSLA.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-03-23  311.250000  311.250000  300.450012  301.540009  301.540009
# 1  2018-03-26  307.339996  307.589996  291.359985  304.179993  304.179993
# 2  2018-03-27  304.000000  304.269989  277.179993  279.179993  279.179993
# 3  2018-03-28  264.579987  268.679993  252.100006  257.779999  257.779999
# 4  2018-03-29  256.489990  270.959991  248.210007  266.130005  266.130005
#
#      Volume
# 0   6654900
# 1   8375200
# 2  13872000
# 3  21001400
# 4  15170700

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
l = len(close) - 1

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / np.std(rewards)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(layer_size, 1),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        buy = np.dot(feed, self.weights[2])
        return decision, buy

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, money, max_buy, max_sell):
        self.model = model
        self.initial_money = money
        self.max_buy = max_buy
        self.max_sell = max_sell
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision, buy = self.model.predict(np.array(sequence))
        return np.argmax(decision[0]), int(buy[0])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = get_state(close, 0, window_size + 1)
        inventory = []
        quantity = 0
        for t in range(0, l, skip):
            action, buy = self.act(state)
            next_state = get_state(close, t + 1, window_size + 1)
            if action == 1 and initial_money >= close[t]:
                if buy < 0:
                    buy = 1
                if buy > self.max_buy:
                    buy_units = self.max_buy
                else:
                    buy_units = buy
                total_buy = buy_units * close[t]
                initial_money -= total_buy
                inventory.append(total_buy)
                quantity += buy_units
            elif action == 2 and len(inventory) > 0:
                if quantity > self.max_sell:
                    sell_units = self.max_sell
                else:
                    sell_units = quantity
                quantity -= sell_units
                total_sell = sell_units * close[t]
                initial_money += total_sell

            state = next_state
        return ((initial_money - starting_money) / starting_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = get_state(close, 0, window_size + 1)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        quantity = 0
        for t in range(0, l, skip):
            action, buy = self.act(state)
            next_state = get_state(close, t + 1, window_size + 1)
            if action == 1 and initial_money >= close[t]:
                if buy < 0:
                    buy = 1
                if buy > self.max_buy:
                    buy_units = self.max_buy
                else:
                    buy_units = buy
                total_buy = buy_units * close[t]
                initial_money -= total_buy
                inventory.append(total_buy)
                quantity += buy_units
                states_buy.append(t)
                print(
                    'day %d: buy %d units at price %f, total balance %f'
                    % (t, buy_units, total_buy, initial_money)
                )
            elif action == 2 and len(inventory) > 0:
                bought_price = inventory.pop(0)
                if quantity > self.max_sell:
                    sell_units = self.max_sell
                else:
                    sell_units = quantity
                if sell_units < 1:
                    continue
                quantity -= sell_units
                total_sell = sell_units * close[t]
                initial_money += total_sell
                states_sell.append(t)
                try:
                    invest = ((total_sell - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (t, sell_units, total_sell, invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        print(
            '\ntotal gained %f, total investment %f %%'
            % (initial_money - starting_money, invest)
        )
        plt.figure(figsize = (20, 10))
        plt.plot(close, label = 'true close', c = 'g')
        plt.plot(
            close, 'X', label = 'predict buy', markevery = states_buy, c = 'b'
        )
        plt.plot(
            close, 'o', label = 'predict sell', markevery = states_sell, c = 'r'
        )
        plt.legend()
        plt.show()

# %%
model = Model(window_size, 500, 3)
agent = Agent(model, 10000, 5, 5)
agent.fit(500, 10)
# Out:
# iter 10. reward: 45.985799
# iter 20. reward: 40.657500
# iter 30. reward: 48.958803
# iter 40. reward: 56.512596
# iter 50. reward: 61.368197
# iter 60. reward: 63.721296
# iter 70. reward: 73.024497
# iter 80. reward: 69.758497
# iter 90. reward: 67.241497
# iter 100. reward: 64.026396
# iter 110. reward: 67.284898
# iter 120. reward: 75.288698
# iter 130. reward: 75.659795
# iter 140. reward: 77.164195
# iter 150. reward: 81.031696
# iter 160. reward: 76.845393
# iter 170. reward: 76.954797
# iter 180. reward: 79.732693
# iter 190. reward: 83.343295
# iter 200. reward: 78.768396
# iter 210. reward: 86.865595
# iter 220. reward: 84.842894
# iter 230. reward: 89.210296
# iter 240. reward: 92.696098
# iter 250. reward: 93.688301
# iter 260. reward: 93.742000
# iter 270. reward: 95.056700
# iter 280. reward: 94.499399
# iter 290. reward: 94.558798
# iter 300. reward: 92.014000
# iter 310. reward: 99.534300
# iter 320. reward: 101.626996
# iter 330. reward: 101.491400
# iter 340. reward: 105.692199
# iter 350. reward: 104.585999
# iter 360. reward: 104.954397
# iter 370. reward: 110.007598
# iter 380. reward: 109.347900
# iter 390. reward: 100.060196
# iter 400. reward: 106.388598
# iter 410. reward: 108.953398
# iter 420. reward: 110.376297
# iter 430. reward: 108.183200
# iter 440. reward: 105.886899
# iter 450. reward: 106.768699
# iter 460. reward: 107.046200
# iter 470. reward: 111.547401
# iter 480. reward: 110.099600
# iter 490. reward: 111.204298
# iter 500. reward: 111.264298
# time taken to train: 86.79438209533691 seconds

# %%
agent.buy()
# Out:
# day 0: buy 5 units at price 1507.700045, total balance 8492.299955
# day 1, sell 5 units at price 1520.899965, investment 0.875500 %, total balance 10013.199920,
# day 2: buy 5 units at price 1395.899965, total balance 8617.299955
# day 3: buy 5 units at price 1288.899995, total balance 7328.399960
# day 4: buy 5 units at price 1330.650025, total balance 5997.749935
# day 5: buy 5 units at price 1262.399980, total balance 4735.349955
# day 6: buy 5 units at price 1337.649995, total balance 3397.699960
# day 7: buy 1 units at price 286.940002, total balance 3110.759958
# day 8: buy 1 units at price 305.720001, total balance 2805.039957
# day 10, sell 5 units at price 1448.300020, investment 3.753855 %, total balance 4253.339977,
# day 11, sell 5 units at price 1523.500060, investment 18.201572 %, total balance 5776.840037,
# day 12, sell 5 units at price 1504.649965, investment 13.076311 %, total balance 7281.490002,
# day 13, sell 5 units at price 1470.399935, investment 16.476549 %, total balance 8751.889937,
# day 14, sell 5 units at price 1501.699980, investment 12.264044 %, total balance 10253.589917,
# day 15: buy 1 units at price 291.209991, total balance 9962.379926
# day 21, sell 3 units at price 850.379973, investment 196.361597 %, total balance 10812.759899,
# day 25: buy 1 units at price 293.899994, total balance 10518.859905
# day 26: buy 1 units at price 299.920013, total balance 10218.939892
# day 28: buy 5 units at price 1422.250060, total balance 8796.689832
# day 29: buy 5 units at price 1470.449980, total balance 7326.239852
# day 33, sell 5 units at price 1525.099945, investment 418.917991 %, total balance 8851.339797,
# day 34, sell 5 units at price 1505.299990, investment 401.900482 %, total balance 10356.639787,
# day 36: buy 5 units at price 1420.899965, total balance 8935.739822
# day 38, sell 5 units at price 1422.700045, investment 0.031639 %, total balance 10358.439867,
# day 39: buy 5 units at price 1384.100035, total balance 8974.339832
# day 40: buy 5 units at price 1422.449950, total balance 7551.889882
# day 41: buy 5 units at price 1375.050050, total balance 6176.839832
# day 42: buy 5 units at price 1395.350035, total balance 4781.489797
# day 44: buy 5 units at price 1394.250030, total balance 3387.239767
# day 45: buy 5 units at price 1418.800050, total balance 1968.439717
# day 46: buy 5 units at price 1458.600005, total balance 509.839712
# day 47: buy 5 units at price 1423.650055, total balance -913.810343
# day 51, sell 5 units at price 1597.500000, investment 8.640214 %, total balance 683.689657,
# day 55, sell 5 units at price 1713.849945, investment 20.617214 %, total balance 2397.539602,
# day 57, sell 5 units at price 1788.600005, investment 29.224764 %, total balance 4186.139607,
# day 58, sell 5 units at price 1790.850065, investment 25.898986 %, total balance 5976.989672,
# day 59, sell 5 units at price 1854.149935, investment 34.842360 %, total balance 7831.139607,
# day 60, sell 5 units at price 1762.749940, investment 26.330304 %, total balance 9593.889547,
# day 61, sell 5 units at price 1811.100005, investment 29.897792 %, total balance 11404.989552,
# day 62, sell 5 units at price 1737.550050, investment 22.466168 %, total balance 13142.539602,
# day 64, sell 2 units at price 666.020020, investment -54.338405 %, total balance 13808.559622,
# day 68: buy 1 units at price 342.950012, total balance 13465.609610
# day 70, sell 1 units at price 310.859985, investment -9.357057 %, total balance 13776.469595,
# day 73: buy 5 units at price 1592.550050, total balance 12183.919545
# day 74: buy 1 units at price 322.470001, total balance 11861.449544
# day 76: buy 5 units at price 1583.549955, total balance 10277.899589
# day 79: buy 1 units at price 322.690002, total balance 9955.209587
# day 80, sell 5 units at price 1619.250030, investment 1.676555 %, total balance 11574.459617,
# day 81, sell 5 units at price 1601.150055, investment 396.526824 %, total balance 13175.609672,
# day 82, sell 2 units at price 627.159974, investment -60.395315 %, total balance 13802.769646,
# day 83: buy 5 units at price 1516.000060, total balance 12286.769586
# day 84: buy 1 units at price 297.429993, total balance 11989.339593
# day 86: buy 5 units at price 1533.249970, total balance 10456.089623
# day 87: buy 5 units at price 1485.899965, total balance 8970.189658
# day 88: buy 5 units at price 1450.850065, total balance 7519.339593
# day 89: buy 5 units at price 1490.700075, total balance 6028.639518
# day 90: buy 5 units at price 1504.199980, total balance 4524.439538
# day 92, sell 5 units at price 1740.850065, investment 439.480633 %, total balance 6265.289603,
# day 94, sell 5 units at price 1897.850035, investment 25.187992 %, total balance 8163.139638,
# day 95, sell 5 units at price 1851.699980, investment 522.566662 %, total balance 10014.839618,
# day 97, sell 5 units at price 1777.449950, investment 15.926952 %, total balance 11792.289568,
# day 98, sell 5 units at price 1782.050020, investment 19.930686 %, total balance 13574.339588,
# day 100, sell 5 units at price 1693.450010, investment 16.721228 %, total balance 15267.789598,
# day 101: buy 1 units at price 335.450012, total balance 14932.339586
# day 102: buy 5 units at price 1527.500000, total balance 13404.839586
# day 104, sell 5 units at price 1609.499970, investment 7.969403 %, total balance 15014.339556,
# day 105: buy 5 units at price 1608.200075, total balance 13406.139481
# day 106, sell 5 units at price 1600.500030, investment 6.402078 %, total balance 15006.639511,
# day 107, sell 2 units at price 645.640014, investment 92.469814 %, total balance 15652.279525,
# day 108: buy 5 units at price 1596.349945, total balance 14055.929580
# day 109: buy 5 units at price 1559.299925, total balance 12496.629655
# day 110, sell 5 units at price 1525.050050, investment -0.160390 %, total balance 14021.679705,
# day 111: buy 5 units at price 1515.749970, total balance 12505.929735
# day 112: buy 1 units at price 301.660004, total balance 12204.269731
# day 113: buy 5 units at price 1444.750060, total balance 10759.519671
# day 114: buy 5 units at price 1403.699950, total balance 9355.819721
# day 116: buy 5 units at price 1316.199950, total balance 8039.619771
# day 119: buy 5 units at price 1452.700045, total balance 6586.919726
# day 121, sell 5 units at price 1476.000060, investment -8.220371 %, total balance 8062.919786,
# day 122: buy 5 units at price 1474.199980, total balance 6588.719806
# day 123: buy 5 units at price 1424.799955, total balance 5163.919851
# day 125: buy 1 units at price 298.329987, total balance 4865.589864
# day 126: buy 5 units at price 1495.500030, total balance 3370.089834
# day 128: buy 1 units at price 300.989990, total balance 3069.099844
# day 130, sell 5 units at price 1537.599945, investment -3.680271 %, total balance 4606.699789,
# day 132, sell 5 units at price 1553.500060, investment -0.371953 %, total balance 6160.199849,
# day 133, sell 5 units at price 1505.099945, investment -0.702624 %, total balance 7665.299794,
# day 134: buy 5 units at price 1473.999940, total balance 6191.299854
# day 135, sell 5 units at price 1409.149935, investment 367.131843 %, total balance 7600.449789,
# day 136: buy 5 units at price 1309.750060, total balance 6290.699729
# day 137: buy 5 units at price 1252.799990, total balance 5037.899739
# day 139: buy 5 units at price 1284.400025, total balance 3753.499714
# day 140: buy 5 units at price 1261.149980, total balance 2492.349734
# day 141: buy 5 units at price 1293.899995, total balance 1198.449739
# day 142: buy 5 units at price 1297.949980, total balance -99.500241
# day 145, sell 5 units at price 1319.550020, investment -8.665862 %, total balance 1220.049779,
# day 147: buy 5 units at price 1304.750060, total balance -84.700281
# day 154, sell 5 units at price 1686.600035, investment 20.153886 %, total balance 1601.899754,
# day 155, sell 5 units at price 1721.399995, investment 30.785599 %, total balance 3323.299749,
# day 157, sell 5 units at price 1706.999970, investment 17.505329 %, total balance 5030.299719,
# day 158: buy 1 units at price 341.059998, total balance 4689.239721
# day 159, sell 5 units at price 1740.800020, investment 18.084388 %, total balance 6430.039741,
# day 163: buy 5 units at price 1693.650055, total balance 4736.389686
# day 164, sell 5 units at price 1720.000000, investment 20.718701 %, total balance 6456.389686,
# day 165, sell 5 units at price 1742.200010, investment 483.984207 %, total balance 8198.589696,
# day 166, sell 5 units at price 1771.549990, investment 18.458706 %, total balance 9970.139686,
# day 167, sell 5 units at price 1767.350005, investment 487.178997 %, total balance 11737.489691,
# day 169, sell 5 units at price 1690.950010, investment 14.718459 %, total balance 13428.439701,
# day 170: buy 5 units at price 1629.149935, total balance 11799.289766
# day 171: buy 1 units at price 346.000000, total balance 11453.289766
# day 172: buy 5 units at price 1719.600065, total balance 9733.689701
# day 173: buy 5 units at price 1739.349975, total balance 7994.339726
# day 175, sell 5 units at price 1752.400055, investment 33.796524 %, total balance 9746.739781,
# day 177, sell 5 units at price 1798.500060, investment 43.558435 %, total balance 11545.239841,
# day 179, sell 5 units at price 1789.850005, investment 39.353003 %, total balance 13335.089846,
# day 180, sell 5 units at price 1825.749970, investment 44.768663 %, total balance 15160.839816,
# day 181, sell 5 units at price 1833.800050, investment 41.726568 %, total balance 16994.639866,
# day 182, sell 5 units at price 1833.000030, investment 41.222702 %, total balance 18827.639896,
# day 184, sell 5 units at price 1828.549955, investment 40.145612 %, total balance 20656.189851,
# day 193: buy 5 units at price 1669.349975, total balance 18986.839876
# day 195: buy 5 units at price 1550.599975, total balance 17436.239901
# day 196: buy 5 units at price 1501.799925, total balance 15934.439976
# day 197, sell 5 units at price 1588.450010, investment -4.846196 %, total balance 17522.889986,
# day 198, sell 5 units at price 1674.799955, investment 8.009801 %, total balance 19197.689941,
# day 200: buy 1 units at price 338.529999, total balance 18859.159942
# day 202: buy 1 units at price 347.260010, total balance 18511.899932
# day 204, sell 5 units at price 1722.149965, investment 14.672397 %, total balance 20234.049897,
# day 205, sell 2 units at price 692.099976, investment 104.442731 %, total balance 20926.149873,
# day 208: buy 1 units at price 298.920013, total balance 20627.229860
# day 209, sell 1 units at price 287.589996, investment -3.790317 %, total balance 20914.819856,
# day 212: buy 1 units at price 296.380005, total balance 20618.439851
# day 213: buy 5 units at price 1487.299955, total balance 19131.139896
# day 214, sell 5 units at price 1543.849945, investment 420.902193 %, total balance 20674.989841,
# day 215: buy 5 units at price 1535.099945, total balance 19139.889896
# day 216: buy 5 units at price 1561.049955, total balance 17578.839941
# day 218, sell 5 units at price 1606.750030, investment 8.031337 %, total balance 19185.589971,
# day 219: buy 1 units at price 317.220001, total balance 18868.369970
# day 221: buy 1 units at price 305.799988, total balance 18562.569982
# day 225, sell 5 units at price 1518.849945, investment -1.058563 %, total balance 20081.419927,
# day 226, sell 3 units at price 923.640015, investment -40.832130 %, total balance 21005.059942,
# day 230: buy 5 units at price 1473.549955, total balance 19531.509987
# day 231, sell 5 units at price 1493.849945, investment 1.377625 %, total balance 21025.359932,
# day 233: buy 5 units at price 1573.699950, total balance 19451.659982
# day 234: buy 1 units at price 319.880005, total balance 19131.779977
# day 236: buy 1 units at price 285.359985, total balance 18846.419992
# day 237, sell 5 units at price 1382.700045, investment -12.136996 %, total balance 20229.120037,
# day 238: buy 5 units at price 1381.199950, total balance 18847.920087
# day 239, sell 5 units at price 1382.949980, investment 332.333987 %, total balance 20230.870067,
# day 240, sell 2 units at price 568.280030, investment 99.144961 %, total balance 20799.150097,
# day 241: buy 1 units at price 290.920013, total balance 20508.230084
# day 244, sell 1 units at price 289.959991, investment -79.006661 %, total balance 20798.190075,
#
# total gained 10798.190075, total investment 107.981901 %
